# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
data = pd.read_excel('C:\\Users\\I559800\\GDP-PRediction\\austr.xlsx')
# data_austr = data[data['Country Name'] == 'Australia']
# austr_values = data_austr.drop(columns='Country Name').values[0].toList()
# print(austr_values)
data.info

sns.relplot(x='Year', y='Income', data=data)
# Out:
# C:\Users\I559800\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
regression_Model = LinearRegression()
regression_Model.fit(data[['Year']].values, data.Income)
regression_Model.predict([[2021]])

# predicted_value = regression_Model.predict([[2021]])
# print(predicted_value)
# Out:
# array([45049.40767515])
